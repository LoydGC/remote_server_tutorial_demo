# %% [markdown]
# # Remote Server Demo
#
# A simple notebook to verify your environment is working.

# %%
print('Hello from Jupyter on the remote server')
# Out:
# Hello from Jupyter on the remote server

# %%
def multiply(a, b):
    return a * b

multiply(6, 100)
# Out:
# 600

# %%
from tqdm import tqdm

print("Hey, look a progress bar")
for i in tqdm(range(100)):
    pass
